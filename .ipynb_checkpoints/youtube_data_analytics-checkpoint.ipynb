# %% [markdown]
# # **When Should You Upload Your Data Videos?**

# %% [markdown]
# <div style="text-align: center;">
#     <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/e1/Logo_of_YouTube_%282015-2017%29.svg/1280px-Logo_of_YouTube_%282015-2017%29.svg.png" width="800"/>
# </div>

# %%
from functions import transform_data, connect_youtube, data_channel_youtube, data_video_youtube
import matplotlib.pyplot as plt
import seaborn as sns

# %%
handles = ["@DarshilParmar",
           "@seattledataguy",
           "@CodeWithYu",
           "@alexmerced-openlakehousead2617",
           "@eczachly_",
           "@kahandatasolutions",
           "@thedataengineeringshow",
           "@AlexTheAnalyst"
          ]

api_service_name = "youtube"
api_version = "v3"
api_key = "Place yor API here"

# %%
youtube = connect_youtube(api_key)
channel_data = data_channel_youtube(youtube,handles)
video_df = data_video_youtube(youtube,channel_data)
df = transform_data(video_df)
df
#df.to_csv('youtube_data', index=False)
# Out:
# Getting video information from channel: Darshil Parmar
# Getting video information from channel: Seattle Data Guy
# Getting video information from channel: CodeWithYu
# Getting video information from channel: Alex Merced - Open Lakehouse Advocate
# Getting video information from channel: Data with Zach
# Getting video information from channel: Kahan Data Solutions
# Getting video information from channel: The Data Engineering Show - Podcast
# Getting video information from channel: Alex The Analyst
#                id      channelTitle  \
# 0     FB4_y25Iifw    Darshil Parmar
# 1     hf2go3E2m8g    Darshil Parmar
# 2     KIqteLTVLy8    Darshil Parmar
# 3     1rW89Sd6HYU    Darshil Parmar
# 4     Ydts27Qa8H0    Darshil Parmar
# ...           ...               ...
# 1169  4rfr6A3lO-Y  Alex The Analyst
# 1170  OTq2NRy_AGs  Alex The Analyst
# 1171  ya28cb3zFGE  Alex The Analyst
# 1172  Hsi2BG0SOiQ  Alex The Analyst
# 1173  6lQzbk6_OTw  Alex The Analyst
#
#                                                   title  \
# 0     Master Apache Airflow: 5 Real-World Projects t...
# 1          Fundamentals Of Data Engineering Masterclass
# 2     Building Your First Data Engineering Portfolio...
# 3     Data Engineering Was Hard Until I Learned Thes...
# 4     Learn Kafka in 10 Minutes | Most Important Ski...
# ...                                                 ...
# 1169  Data Analyst Resume | Reviewing My Resume! | F...
# 1170  Working at a Big Company Vs Small Company | To...
# 1171      Data Analyst Salary | 100k with No Experience
# 1172  Truth About Big Companies | Told by a Fortune ...
# 1173                  Top 3 Data Analyst Skills in 2020
#
#                                             description  \
# 0     Get the Apache Airflow Course Here -  https://...
# 1     Combo Package Python + SQL + Data warehouse (S...
# 2     Check Out My Data Engineering Bootcamp: https:...
# 3     ➡️ Check Out My Data Engineering Bootcamp: htt...
# 4     Check Out My Data Engineering Bootcamp: https:...
# ...                                                 ...
# 1169  Data Analyst Resume | Reviewing My Resume! | F...
# 1170  Working at a Big Company Vs Small Company | To...
# 1171  Data Analyst Salary | 100k with No Experience ...
# 1172  Truth About Big Companies // There are a ton o...
# 1173  Top 3 Data Analyst Skills in 2020 // There are...
#
#                                                    tags  viewCount  likeCount  \
# 0     darshil parmar, Best Apache Airflow Course for...    10971.0      334.0
# 1     darshil parmar, fundamentals of data engineeri...   106534.0     4614.0
# 2     darshil parmar, data engineering, data enginee...    23662.0      704.0
# 3     darshil parmar data engineer project, apache s...    48220.0     2322.0
# 4     Learn Apache Kafka in 10 Minutes | Step by Ste...    34020.0     1213.0
# ...                                                 ...        ...        ...
# 1169  Data Analyst, How to become a data analyst, Da...    76307.0     1708.0
# 1170  Data Analyst, How to become a Data Analyst, Bi...    15491.0      414.0
# 1171  Data Analyst Salary, Data analyst with no expe...    65582.0     2224.0
# 1172  Working at a big company, Big company data ana...     9290.0      336.0
# 1173  Top skills for data analyst, Top 3 skills for ...    29752.0     1426.0
#
#       favoriteCount  commentCount  duration definition caption publishedOn  \
# 0               0.0         101.0     798.0         hd    true      Sunday
# 1               0.0         377.0   10946.0         hd    true      Sunday
# 2               0.0          53.0    1385.0         hd    true      Sunday
# 3               0.0         101.0     463.0         hd   false      Monday
# 4               0.0          72.0     765.0         hd    true      Sunday
# ...             ...           ...       ...        ...     ...         ...
# 1169            0.0          63.0     453.0         hd   false    Thursday
# 1170            0.0          22.0     350.0         hd   false    Saturday
# 1171            0.0         231.0     303.0         hd   false    Thursday
# 1172            0.0          20.0     345.0         hd   false     Tuesday
# 1173            0.0         142.0     160.0         hd   false      Friday
#
#      datepublished timepublished
# 0       2024-08-25      14:00:12
# 1       2024-08-18      13:05:41
# 2       2024-08-04      13:30:03
# 3       2024-07-08      15:44:34
# 4       2024-06-30      13:28:13
# ...            ...           ...
# 1169    2020-01-30      14:07:55
# 1170    2020-01-25      16:38:39
# 1171    2020-01-23      03:16:09
# 1172    2020-01-21      03:52:15
# 1173    2020-01-17      14:31:39
#
# [1174 rows x 15 columns]

# %%
dfcount = df.groupby('channelTitle').size().reset_index(name='upload_count')
dfcount
# Out:
#                             channelTitle  upload_count
# 0  Alex Merced - Open Lakehouse Advocate            19
# 1                       Alex The Analyst           329
# 2                             CodeWithYu            67
# 3                         Darshil Parmar           157
# 4                         Data with Zach            52
# 5                   Kahan Data Solutions           208
# 6                       Seattle Data Guy           279
# 7    The Data Engineering Show - Podcast            63

# %%
df_grouped = df.groupby(['publishedOn']).agg({'viewCount': 'sum', 'id': 'count'}).reset_index()

# Calculate the view count per video for each day
df_grouped['view_per_video_ratio'] = df_grouped['viewCount'] / df_grouped['id']

# Order of days of the week
days_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
view_counts_by_day = df_grouped.set_index('publishedOn').reindex(days_order)

# Plot the data
plt.figure(figsize=(10, 6))
view_counts_by_day['view_per_video_ratio'].plot(kind='bar', color='#CD201F')

# Add labels and title
plt.xlabel('Day of the Week')
plt.ylabel('View Count per Video Ratio')
plt.title('View Count per Video Ratio by Day of the Week')
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #### It's Sunday, not so surprised. but Tuesday is crazyly high too, so let's take a look into each channel stat.

# %%
df_grouped = df.groupby(['channelTitle', 'publishedOn']).agg({'viewCount': 'sum', 'id': 'count'}).reset_index()
df_grouped['view_per_video_ratio'] = df_grouped['viewCount'] / df_grouped['id']

# Create a pivot table for easier plotting
df_pivot = df_grouped.pivot(index='publishedOn', columns='channelTitle', values='view_per_video_ratio').fillna(0)

# Set up the number of channels and the number of rows and columns for the subplot
channels = df_pivot.columns
num_channels = len(channels)
ncols = 2
nrows = (num_channels + ncols - 1) // ncols  # Number of rows needed

# Create the subplots
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(15, nrows * 4), squeeze=False)
axes = axes.flatten()
days_of_week = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# Reindex the pivot table to match the days of the week
df_pivot = df_pivot.reindex(days_of_week)

# Iterate through each unique channel and create a bar plot
for i, channel in enumerate(channels):
    sns.barplot(x=df_pivot.index, y=df_pivot[channel], ax=axes[i], color='#CD201F')
    axes[i].set_title(f'{channel}', fontsize=14)
    axes[i].set_xlabel(' ', fontsize=12)
    axes[i].set_ylabel('View Count per Video Ratio', fontsize=12)
    axes[i].set_ylim(0, df_pivot[channel].max() * 1.2)

# Hide any empty subplots if the number of channels is not a perfect square
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.suptitle('View Count per Video Ratio by Channel and Day of the Week', fontsize=18, y=1.02)
plt.show()

# %% [markdown]
# #### Here is the stats for each channel, Sunday though, still the best day for uploading new video. Saturday, on the other hand, is not likely to be a great choise of uploading video.

# %% [markdown]
# #### Look at Alex the analyist, his videos have highest view per video highest on Sunday, although he uploads mostly on Tuesday. Guy should change his strategy.

# %%
tuesday_df = df[df['publishedOn'] == 'Tuesday']
tuesday_uploads = tuesday_df.groupby('channelTitle').size().reset_index(name='upload_count')
#most_tuesday_uploads = tuesday_uploads.loc[tuesday_uploads['upload_count'].idxmax()]
print(tuesday_uploads)
# Out:
#                             channelTitle  upload_count
# 0  Alex Merced - Open Lakehouse Advocate             5
# 1                       Alex The Analyst           203
# 2                             CodeWithYu             5
# 3                         Darshil Parmar             6
# 4                         Data with Zach             4
# 5                   Kahan Data Solutions            16
# 6                       Seattle Data Guy            52
# 7    The Data Engineering Show - Podcast            18
